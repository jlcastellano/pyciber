# %% [markdown]
# # Tema 01: Ejercicios Prácticos
#
# **Nivel de dificultad:**
# - 🟢 Básico
# - 🟡 Intermedio
# - 🔴 Avanzado

# %% [markdown]
# ---
# ## Bloque 1: Manipulación de Strings Básica

# %% [markdown]
# ### Ejercicio 1: Extracción de Protocolo 🟢
#
# Dada la URL `url = "https://www.example.com/login"`, extrae:
# 1. El protocolo ("https")
# 2. El dominio ("www.example.com")
# 3. La ruta ("/login")
#
# **Pista:** Usa slicing y el método `.find()`

# %%
# Escribe tu código aquí
url = "https://www.example.com/login"

# %% [markdown]
# ### Ejercicio 2: Validación de IP 🟢
#
# Dada la IP `ip = "192.168.1.100"`, verifica que:
# 1. Tiene exactamente 4 octetos
# 2. Todos los octetos son números
# 3. Imprime cada octeto por separado
#
# **Pista:** Usa `.split()` y `.isdigit()`

# %%
# Escribe tu código aquí
ip = "192.168.1.100"

# %% [markdown]
# ### Ejercicio 3: Limpieza de Usuario 🟢
#
# Dado el input de usuario `entrada = "   AdMiN123   \n"`, realiza:
# 1. Elimina espacios en blanco al inicio y final
# 2. Convierte todo a minúsculas
# 3. Verifica si es alfanumérico
# 4. Imprime el resultado limpio

# %%
# Escribe tu código aquí
entrada = "   AdMiN123   \n"

# %% [markdown]
# ### Ejercicio 4: Análisis de Banner 🟡
#
# Dado el banner:
# ```python
# banner = "SSH-2.0-OpenSSH_8.2p1 Ubuntu-4ubuntu0.5"
# ```
#
# Extrae:
# 1. La versión del protocolo ("2.0")
# 2. El software ("OpenSSH")
# 3. La versión del software ("8.2p1")
# 4. El sistema operativo ("Ubuntu")
#
# **Pista:** Usa `.split()` con diferentes separadores

# %%
# Escribe tu código aquí
banner = "SSH-2.0-OpenSSH_8.2p1 Ubuntu-4ubuntu0.5"

# %% [markdown]
# ### Ejercicio 5: Inversión de Hash 🟢
#
# Dado un hash MD5 en hexadecimal:
# ```python
# hash_md5 = "5f4dcc3b5aa765d61d8327deb882cf99"
# ```
#
# 1. Invierte el string completo
# 2. Convierte todo a mayúsculas
# 3. Divide en grupos de 4 caracteres separados por guiones
#
# Resultado esperado: `"99FC-288B-ED72-83D1-16D5-67AA-5B3B-CC4D-5F"`

# %%
# Escribe tu código aquí
hash_md5 = "5f4dcc3b5aa765d61d8327deb882cf99"

# %% [markdown]
# ---
# ## Bloque 2: Formateo de Strings

# %% [markdown]
# ### Ejercicio 6: Reporte de Escaneo 🟢
#
# Crea un reporte formateado con los siguientes datos:
# ```python
# ip = "192.168.1.50"
# hostname = "server01"
# puertos_abiertos = 3
# tiempo = 2.3456
# ```
#
# El reporte debe verse así:
# ```
# ========== REPORTE DE ESCANEO ==========
# IP:               192.168.1.50
# Hostname:         server01
# Puertos abiertos: 3
# Tiempo:           2.35 segundos
# ========================================
# ```
#
# **Pista:** Usa f-strings con formateo de alineación y decimales

# %%
# Escribe tu código aquí
ip = "192.168.1.50"
hostname = "server01"
puertos_abiertos = 3
tiempo = 2.3456

# %% [markdown]
# ### Ejercicio 7: Conversión de Formatos 🟡
#
# Dado el número decimal `ip_decimal = 3232235777`:
#
# 1. Convierte a hexadecimal
# 2. Convierte a binario
# 3. Convierte a formato IP (192.168.1.1)
#
# **Pista para IP:** Divide el número en 4 octetos usando operaciones de bits o división

# %%
# Escribe tu código aquí
ip_decimal = 3232235777

# %% [markdown]
# ### Ejercicio 8: Tabla de Puertos 🟡
#
# Crea una tabla formateada con estos datos:
# ```python
# servicios = [
#     (22, "SSH", "abierto"),
#     (80, "HTTP", "abierto"),
#     (443, "HTTPS", "cerrado"),
#     (8080, "HTTP-Alt", "abierto")
# ]
# ```
#
# Debe verse así:
# ```
# PUERTO | SERVICIO  | ESTADO
# -------|-----------|----------
#     22 | SSH       | abierto
#     80 | HTTP      | abierto
#    443 | HTTPS     | cerrado
#   8080 | HTTP-Alt  | abierto
# ```

# %%
# Escribe tu código aquí
servicios = [
    (22, "SSH", "abierto"),
    (80, "HTTP", "abierto"),
    (443, "HTTPS", "cerrado"),
    (8080, "HTTP-Alt", "abierto")
]

# %% [markdown]
# ---
# ## Bloque 3: Conversión de Tipos

# %% [markdown]
# ### Ejercicio 9: MAC Address Converter 🟡
#
# Dada una MAC address en diferentes formatos, conviértela al formato estándar:
#
# ```python
# mac1 = "00:1A:2B:3C:4D:5E"  # Formato con dos puntos
# mac2 = "001a2b3c4d5e"        # Formato sin separadores
# ```
#
# Convierte ambas a:
# 1. Formato con guiones: `"00-1A-2B-3C-4D-5E"`
# 2. Lista de bytes: `[0, 26, 43, 60, 77, 94]`
# 3. Valor decimal completo

# %%
# Escribe tu código aquí
mac1 = "00:1A:2B:3C:4D:5E"
mac2 = "001a2b3c4d5e"

# %% [markdown]
# ### Ejercicio 10: IP a Bytes y Viceversa 🟡
#
# Crea dos funciones:
#
# 1. `ip_a_bytes(ip_string)`: Convierte "192.168.1.1" a bytes
# 2. `bytes_a_ip(ip_bytes)`: Convierte bytes de vuelta a string
#
# Pruébalas con:
# ```python
# ip = "10.0.0.255"
# bytes_ip = ip_a_bytes(ip)
# ip_recuperada = bytes_a_ip(bytes_ip)
# print(f"{ip} == {ip_recuperada}")  # Debe ser True
# ```

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 11: Conversión de Puertos 🟢
#
# Dado el string:
# ```python
# puertos_str = "22,80,443,8080,3306"
# ```
#
# 1. Convierte a lista de enteros
# 2. Filtra solo los puertos mayores a 100
# 3. Convierte de vuelta a string con formato: "Puerto: 443, Puerto: 8080, Puerto: 3306"

# %%
# Escribe tu código aquí
puertos_str = "22,80,443,8080,3306"

# %% [markdown]
# ---
# ## Bloque 4: Listas Básicas

# %% [markdown]
# ### Ejercicio 12: Gestión de Targets 🟢
#
# Crea una lista `targets` vacía y:
# 1. Añade las IPs: "192.168.1.1", "192.168.1.10", "192.168.1.50"
# 2. Inserta "192.168.1.5" en la posición correcta (ordenado)
# 3. Elimina la última IP
# 4. Imprime el número total de targets
# 5. Verifica si "192.168.1.10" está en la lista

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 13: Top Puertos 🟢
#
# Dada la lista de puertos escaneados:
# ```python
# puertos = [8080, 22, 443, 80, 21, 3306, 5432, 8443]
# ```
#
# 1. Ordena los puertos de menor a mayor
# 2. Obtén los 3 puertos más bajos
# 3. Obtén los 3 puertos más altos
# 4. Invierte la lista completa

# %%
# Escribe tu código aquí
puertos = [8080, 22, 443, 80, 21, 3306, 5432, 8443]

# %% [markdown]
# ### Ejercicio 14: Log de Intentos 🟡
#
# Dada la lista de resultados de login:
# ```python
# logs = ["fail", "fail", "fail", "success", "fail", "fail", "success"]
# ```
#
# 1. Cuenta cuántos intentos fallidos hay
# 2. Cuenta cuántos intentos exitosos hay
# 3. Encuentra la posición del primer éxito
# 4. Calcula el porcentaje de éxito
# 5. Crea una nueva lista solo con los intentos únicos

# %%
# Escribe tu código aquí
logs = ["fail", "fail", "fail", "success", "fail", "fail", "success"]

# %% [markdown]
# ### Ejercicio 15: Merge de Listas 🟡
#
# Tienes dos listas de puertos de diferentes escaneos:
# ```python
# escaneo1 = [22, 80, 443]
# escaneo2 = [80, 443, 8080, 3306]
# ```
#
# 1. Combina ambas listas
# 2. Elimina duplicados
# 3. Ordena el resultado
# 4. Encuentra los puertos que están en ambos escaneos
# 5. Encuentra los puertos únicos de cada escaneo

# %%
# Escribe tu código aquí
escaneo1 = [22, 80, 443]
escaneo2 = [80, 443, 8080, 3306]

# %% [markdown]
# ---
# ## Bloque 5: Tuplas

# %% [markdown]
# ### Ejercicio 16: Información de Servicio 🟢
#
# Crea tuplas para representar servicios:
# ```python
# servicio_ssh = (22, "SSH", "TCP", "OpenSSH 8.2")
# servicio_http = (80, "HTTP", "TCP", "Apache 2.4")
# ```
#
# 1. Desempaqueta cada tupla en variables separadas
# 2. Imprime la información formateada
# 3. Intenta modificar el puerto (debe dar error)
# 4. Crea una lista de tuplas con ambos servicios

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 17: Coordenadas de Red 🟡
#
# Usa tuplas para representar conexiones (IP, Puerto):
# ```python
# conexiones = [
#     ("192.168.1.1", 22),
#     ("192.168.1.1", 80),
#     ("192.168.1.2", 443),
#     ("192.168.1.1", 22)  # Duplicado
# ]
# ```
#
# 1. Elimina conexiones duplicadas
# 2. Ordena por IP, luego por puerto
# 3. Agrupa las conexiones por IP
# 4. Cuenta cuántas conexiones hay por cada IP

# %%
# Escribe tu código aquí
conexiones = [
    ("192.168.1.1", 22),
    ("192.168.1.1", 80),
    ("192.168.1.2", 443),
    ("192.168.1.1", 22)
]

# %% [markdown]
# ### Ejercicio 18: Retorno Múltiple 🟡
#
# Crea una función `analizar_puerto(puerto)` que retorne una tupla con:
# - Si es un puerto conocido (21, 22, 23, 80, 443)
# - El nombre del servicio (o "Desconocido")
# - Si es puerto bajo (< 1024) o alto
#
# Ejemplo:
# ```python
# resultado = analizar_puerto(22)
# # (True, "SSH", "bajo")
# ```

# %%
# Escribe tu código aquí

# %% [markdown]
# ---
# ## Bloque 6: Diccionarios Básicos

# %% [markdown]
# ### Ejercicio 19: Registro de Host 🟢
#
# Crea un diccionario para un host con:
# - IP: "192.168.1.100"
# - Hostname: "webserver"
# - OS: "Ubuntu 20.04"
# - Puertos abiertos: [80, 443]
#
# Luego:
# 1. Añade la MAC address: "00:11:22:33:44:55"
# 2. Actualiza el OS a "Ubuntu 22.04"
# 3. Añade el puerto 22 a la lista de puertos abiertos
# 4. Imprime toda la información

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 20: Mapeado de Servicios 🟢
#
# Crea un diccionario que mapee puertos a servicios:
# ```python
# {
#     21: "FTP",
#     22: "SSH",
#     80: "HTTP",
#     443: "HTTPS"
# }
# ```
#
# 1. Añade los puertos: 25 (SMTP), 3306 (MySQL)
# 2. Obtén el servicio del puerto 22
# 3. Verifica si el puerto 8080 está en el diccionario
# 4. Imprime todos los puertos disponibles
# 5. Imprime todos los servicios disponibles

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 21: Contador de Eventos 🟡
#
# Dado un log de eventos:
# ```python
# eventos = ["login", "logout", "login", "failed", "login", "logout", "failed", "failed"]
# ```
#
# Crea un diccionario que cuente cuántas veces ocurre cada evento.
#
# Resultado esperado:
# ```python
# {
#     "login": 3,
#     "logout": 2,
#     "failed": 3
# }
# ```

# %%
# Escribe tu código aquí
eventos = ["login", "logout", "login", "failed", "login", "logout", "failed", "failed"]

# %% [markdown]
# ### Ejercicio 22: Inventario de Credenciales 🟡
#
# Crea un diccionario de credenciales comunes:
# ```python
# credenciales = {
#     "admin": "admin",
#     "root": "toor",
#     "user": "password"
# }
# ```
#
# 1. Añade 3 combinaciones más
# 2. Verifica si existe el usuario "admin"
# 3. Verifica si la contraseña "admin" está en algún valor
# 4. Imprime todas las combinaciones en formato "usuario:contraseña"
# 5. Cuenta cuántas credenciales tienes en total

# %%
# Escribe tu código aquí
credenciales = {
    "admin": "admin",
    "root": "toor",
    "user": "password"
}

# %% [markdown]
# ---
# ## Bloque 7: Diccionarios Anidados

# %% [markdown]
# ### Ejercicio 23: Red de Hosts 🔴
#
# Crea una estructura de diccionarios anidados para representar una red:
#
# ```python
# red = {
#     "192.168.1.1": {
#         "hostname": "router",
#         "tipo": "gateway",
#         "puertos": [80, 443]
#     },
#     "192.168.1.10": {
#         "hostname": "server01",
#         "tipo": "servidor",
#         "puertos": [22, 80, 3306]
#     }
# }
# ```
#
# 1. Añade un tercer host: 192.168.1.20 (workstation, puertos 445, 3389)
# 2. Añade el puerto 8080 al router
# 3. Imprime todos los hostnames
# 4. Cuenta el total de puertos únicos en toda la red
# 5. Encuentra qué hosts tienen el puerto 80 abierto

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 24: Escaneo Completo 🔴
#
# Crea una estructura para almacenar resultados de escaneo detallado:
#
# ```python
# escaneo = {
#     "192.168.1.100": {
#         "hostname": "webserver",
#         "os": "Linux",
#         "servicios": {
#             22: {"nombre": "SSH", "version": "OpenSSH 8.2", "estado": "abierto"},
#             80: {"nombre": "HTTP", "version": "Apache 2.4", "estado": "abierto"}
#         }
#     }
# }
# ```
#
# 1. Añade el servicio MySQL en puerto 3306 (version 5.7)
# 2. Cambia el estado del puerto 80 a "filtrado"
# 3. Imprime todos los servicios abiertos con su versión
# 4. Cuenta cuántos puertos están abiertos
# 5. Lista todos los servicios que contienen "Apache" en su versión

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 25: Base de Datos de Vulnerabilidades 🔴
#
# Crea una estructura para gestionar vulnerabilidades:
#
# ```python
# vulnerabilidades = {
#     "CVE-2021-44228": {
#         "nombre": "Log4Shell",
#         "severidad": "CRITICA",
#         "cvss": 10.0,
#         "afectados": ["Apache Log4j 2.0-2.14.1"],
#         "puertos": [8080, 443]
#     }
# }
# ```
#
# 1. Añade otra vulnerabilidad: CVE-2017-0144 (EternalBlue, CRITICA, CVSS 8.1, afecta SMBv1, puerto 445)
# 2. Filtra solo las vulnerabilidades CRITICAS
# 3. Encuentra vulnerabilidades que afecten al puerto 443
# 4. Calcula el promedio del CVSS score
# 5. Ordena las vulnerabilidades por CVSS (de mayor a menor)

# %%
# Escribe tu código aquí

# %% [markdown]
# ---
# ## Bloque 8: Proyectos Integradores

# %% [markdown]
# ### Ejercicio 26: Parser de Logs 🔴
#
# Dado un log de accesos web:
# ```python
# logs = [
#     "192.168.1.50 - GET /admin 403",
#     "192.168.1.51 - POST /login 200",
#     "192.168.1.50 - GET /admin 403",
#     "192.168.1.52 - GET /index 200",
#     "192.168.1.50 - GET /admin 403"
# ]
# ```
#
# Crea una estructura de datos que:
# 1. Agrupe los intentos por IP
# 2. Cuente cuántas veces cada IP intentó acceder a /admin
# 3. Cuente los códigos de respuesta (200, 403, etc.)
# 4. Identifique IPs con múltiples intentos 403
# 5. Genere un reporte formateado con la información

# %%
# Escribe tu código aquí
logs = [
    "192.168.1.50 - GET /admin 403",
    "192.168.1.51 - POST /login 200",
    "192.168.1.50 - GET /admin 403",
    "192.168.1.52 - GET /index 200",
    "192.168.1.50 - GET /admin 403"
]

# %% [markdown]
# ### Ejercicio 27: Generador de Wordlist 🔴
#
# Crea un sistema que genere wordlists personalizadas:
#
# Componentes:
# ```python
# palabras_base = ["admin", "user", "test"]
# sufijos = ["123", "2024", "!", "@"]
# variaciones = ["upper", "lower", "capitalize"]
# ```
#
# El sistema debe:
# 1. Generar todas las combinaciones de palabra + sufijo
# 2. Aplicar las variaciones de capitalización
# 3. Eliminar duplicados
# 4. Contar el total de contraseñas generadas
# 5. Mostrar las primeras 20
# 6. Guardar todo en una lista
#
# **Bono:** Añade prefijos y genera combinaciones prefijo+palabra+sufijo

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 28: Sistema de Gestión de Red 🔴
#
# Crea un sistema completo de gestión de red que incluya:
#
# 1. Función `agregar_host(red, ip, datos)` - añade un nuevo host
# 2. Función `actualizar_puerto(red, ip, puerto, estado)` - actualiza estado de puerto
# 3. Función `buscar_servicio(red, servicio)` - encuentra hosts con un servicio
# 4. Función `hosts_vulnerables(red)` - lista hosts con puertos críticos abiertos (21, 23, 445)
# 5. Función `generar_reporte(red)` - genera reporte completo de la red
#
# Estructura de datos:
# ```python
# red = {
#     "192.168.1.1": {
#         "hostname": "router",
#         "os": "RouterOS",
#         "servicios": {
#             22: {"nombre": "SSH", "estado": "abierto"},
#             80: {"nombre": "HTTP", "estado": "abierto"}
#         }
#     }
# }
# ```
#
# Prueba todas las funciones con una red de al menos 3 hosts.

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 29: Analizador de Banners 🔴
#
# Crea un sistema que analice banners de servicios y extraiga información:
#
# Banners de ejemplo:
# ```python
# banners = [
#     "SSH-2.0-OpenSSH_8.2p1 Ubuntu-4ubuntu0.5",
#     "220 ProFTPD 1.3.5 Server (Debian)",
#     "HTTP/1.1 200 OK\r\nServer: Apache/2.4.41 (Ubuntu)\r\n",
#     "MySQL 5.7.33-0ubuntu0.18.04.1"
# ]
# ```
#
# El analizador debe:
# 1. Identificar el tipo de servicio (SSH, FTP, HTTP, MySQL)
# 2. Extraer la versión del software
# 3. Identificar el sistema operativo si está presente
# 4. Detectar versiones conocidas como vulnerables (define tú algunas)
# 5. Generar un diccionario con toda la información
# 6. Crear un reporte de seguridad
#
# **Bonus:** Investiga vulnerabilidades reales para las versiones detectadas

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 30: Simulador de Fuerza Bruta 🔴
#
# Crea un simulador de ataque de fuerza bruta que:
#
# 1. Tenga un diccionario de credenciales "correctas":
# ```python
# credenciales_validas = {
#     "admin": "Admin123!",
#     "root": "Toor2024",
#     "user": "Password1"
# }
# ```
#
# 2. Tenga listas de usuarios y contraseñas comunes para probar
#
# 3. Simule intentos de login y:
#    - Cuente intentos totales
#    - Registre intentos exitosos
#    - Registre intentos fallidos por usuario
#    - Calcule el tiempo simulado (0.1s por intento)
#    - Implemente un "lockout" después de 3 intentos fallidos por usuario
#
# 4. Genere un reporte completo:
#    - Total de intentos
#    - Credenciales encontradas
#    - Tiempo total
#    - Usuarios bloqueados
#    - Tasa de éxito
#
# **Nota:** Esto es solo para entender cómo funcionan estos ataques. Nunca lo uses sin autorización.

# %%
# Escribe tu código aquí
