# %% [markdown]
# # Tema 02: Ejercicios Prácticos - Control de Flujo y Funciones
# ## Condicionales, Bucles y Funciones
#
# **Nivel de dificultad:**
# - 🟢 Básico
# - 🟡 Intermedio
# - 🔴 Avanzado

# %% [markdown]
# ---
# ## Bloque 1: Estructuras Condicionales

# %% [markdown]
# ### Ejercicio 1: Clasificador de Puertos 🟢
#
# Dado un número de puerto, clasifícalo según estas reglas:
# - Puertos 0-1023: "Puerto privilegiado/sistema"
# - Puertos 1024-49151: "Puerto registrado"
# - Puertos 49152-65535: "Puerto dinámico/privado"
# - Fuera de rango: "Puerto inválido"
#
# Además, si el puerto es uno de estos comunes, indica su servicio:
# - 21: FTP
# - 22: SSH
# - 80: HTTP
# - 443: HTTPS
#
# **Pista:** Usa `if-elif-else` anidados

# %%
# Escribe tu código aquí
puerto = 22

# Tu solución:

# %% [markdown]
# ### Ejercicio 2: Validador de Credenciales 🟢
#
# Crea un sistema simple de autenticación que:
# 1. Verifique si el usuario es "admin" Y la contraseña es "secret123"
# 2. Si el usuario es correcto pero la contraseña incorrecta: "Contraseña incorrecta"
# 3. Si el usuario es incorrecto: "Usuario no encontrado"
# 4. Si ambos son correctos: "Acceso concedido"
#
# **Pista:** Usa operadores lógicos `and` y condiciones anidadas

# %%
# Escribe tu código aquí
usuario_ingresado = "admin"
password_ingresada = "secret123"

# Datos correctos
usuario_correcto = "admin"
password_correcta = "secret123"

# Tu solución:

# %% [markdown]
# ### Ejercicio 3: Analizador de Código HTTP 🟡
#
# Dado un código de respuesta HTTP, determina:
# 1. La categoría (1xx Informativo, 2xx Éxito, 3xx Redirección, 4xx Error Cliente, 5xx Error Servidor)
# 2. El nivel de severidad:
#    - 200, 201, 204: "BAJO - Respuesta normal"
#    - 301, 302, 304: "BAJO - Redirección"
#    - 400, 404: "MEDIO - Error de cliente"
#    - 401, 403: "ALTO - Problema de acceso"
#    - 500, 502, 503: "CRÍTICO - Error de servidor"
#
# **Pista:** Usa operadores de comparación (`//` para división entera)

# %%
# Escribe tu código aquí
codigo = 404

# Tu solución:

# %% [markdown]
# ### Ejercicio 4: Detector de IPs Privadas 🟡
#
# Dada una IP en formato string, determina si es:
# - IP privada clase A: 10.0.0.0 - 10.255.255.255
# - IP privada clase B: 172.16.0.0 - 172.31.255.255
# - IP privada clase C: 192.168.0.0 - 192.168.255.255
# - Localhost: 127.0.0.0 - 127.255.255.255
# - IP pública: cualquier otra
#
# **Pista:** Divide la IP por puntos y convierte a enteros

# %%
# Escribe tu código aquí
ip = "192.168.1.100"

# Tu solución:

# %% [markdown]
# ### Ejercicio 5: Operador Ternario - Estado de Servicios 🟢
#
# Dado un diccionario con estados de servicios:
# ```python
# servicios = {
#     "ssh": True,
#     "http": False,
#     "mysql": True,
#     "ftp": False
# }
# ```
#
# Para cada servicio, imprime:
# - Si está activo: `"[✓] servicio: ACTIVO"`
# - Si está inactivo: `"[✗] servicio: INACTIVO"`
#
# **Pista:** Usa operador ternario en un bucle `for`

# %%
# Escribe tu código aquí
servicios = {
    "ssh": True,
    "http": False,
    "mysql": True,
    "ftp": False
}

# Tu solución:

# %% [markdown]
# ---
# ## Bloque 2: Bucles FOR

# %% [markdown]
# ### Ejercicio 6: Escáner de Rango de Puertos 🟢
#
# Simula un escaneo de puertos del 20 al 25. Para cada puerto:
# 1. Imprime `"Escaneando puerto X..."`
# 2. Si el puerto es 22 o 23, indica que está "abierto"
# 3. Para los demás, indica que está "cerrado"
#
# **Pista:** Usa `range()` y condicionales dentro del bucle

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 7: Generador de IPs 🟢
#
# Genera todas las IPs del rango 192.168.1.1 hasta 192.168.1.10.
# Imprime cada una en formato: `"192.168.1.X"`
#
# **Pista:** Usa `range()` para el último octeto

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 8: Análisis de Log con enumerate() 🟡
#
# Dado este log de eventos:
# ```python
# log = [
#     "login exitoso",
#     "intento fallido",
#     "intento fallido",
#     "login exitoso",
#     "intento fallido"
# ]
# ```
#
# Para cada evento:
# 1. Muestra el número de línea (empezando en 1)
# 2. Muestra el evento
# 3. Si es "intento fallido", añade ⚠️
#
# **Pista:** Usa `enumerate(log, start=1)`

# %%
# Escribe tu código aquí
log = [
    "login exitoso",
    "intento fallido",
    "intento fallido",
    "login exitoso",
    "intento fallido"
]

# Tu solución:

# %% [markdown]
# ### Ejercicio 9: Correlación de Datos con zip() 🟡
#
# Tienes tres listas paralelas:
# ```python
# ips = ["192.168.1.1", "192.168.1.2", "192.168.1.3"]
# puertos = [22, 80, 443]
# estados = ["abierto", "cerrado", "abierto"]
# ```
#
# Imprime un reporte formateado:
# ```
# [+] 192.168.1.1:22 - abierto
# [-] 192.168.1.2:80 - cerrado
# [+] 192.168.1.3:443 - abierto
# ```
#
# Usa `[+]` para abiertos y `[-]` para cerrados.
#
# **Pista:** Usa `zip()` y operador ternario

# %%
# Escribe tu código aquí
ips = ["192.168.1.1", "192.168.1.2", "192.168.1.3"]
puertos = [22, 80, 443]
estados = ["abierto", "cerrado", "abierto"]

# Tu solución:

# %% [markdown]
# ### Ejercicio 10: List Comprehension - Filtrado 🟡
#
# Dado un rango de puertos del 1 al 100:
# 1. Crea una lista con todos los puertos pares usando list comprehension
# 2. Crea otra lista con los puertos mayores a 50 y menores a 75
# 3. Crea una lista con los puertos divisibles por 5
#
# **Pista:** Usa `[expresion for x in iterable if condicion]`

# %%
# Escribe tu código aquí

# %% [markdown]
# ---
# ## Bloque 3: Bucles WHILE

# %% [markdown]
# ### Ejercicio 11: Contador de Intentos de Login 🟢
#
# Simula un sistema de login con máximo 3 intentos:
# 1. Usa un bucle `while` que permita hasta 3 intentos
# 2. En cada intento, incrementa el contador
# 3. Si el intento es el número 2, simula un login exitoso y termina el bucle
# 4. Si se agotan los intentos, muestra "Cuenta bloqueada"
#
# **Pista:** Usa una variable contador y `break`

# %%
# Escribe tu código aquí
max_intentos = 3
intento_actual = 0

# Tu solución:

# %% [markdown]
# ### Ejercicio 12: Búsqueda de Puerto Abierto 🟡
#
# Dado un rango de puertos, busca el primer puerto abierto:
# ```python
# puertos = [21, 22, 23, 80, 443, 3306, 8080]
# puertos_abiertos = [80, 3306]  # Simula cuáles están abiertos
# ```
#
# 1. Usa `while` con un índice para recorrer la lista
# 2. Cuando encuentres un puerto abierto, imprime un mensaje y sal del bucle
# 3. Si no encuentras ninguno, muestra "No hay puertos abiertos"
#
# **Pista:** Usa una variable índice y `break`

# %%
# Escribe tu código aquí
puertos = [21, 22, 23, 80, 443, 3306, 8080]
puertos_abiertos = [80, 3306]

# Tu solución:

# %% [markdown]
# ### Ejercicio 13: Menú Interactivo Simple 🟡
#
# Crea un menú que se repita hasta que el usuario elija salir:
#
# ```
# === MENÚ ===
# 1. Escanear red
# 2. Ver logs
# 3. Salir
# ```
#
# 1. Usa `while True`
# 2. Lee la opción del usuario (simúlala con una variable)
# 3. Según la opción, imprime un mensaje diferente
# 4. Si elige 3, sal del bucle con `break`
# 5. Si elige una opción inválida, muestra "Opción no válida"
#
# **Nota:** Para simular sin input(), usa una lista de opciones predefinidas
#
# **Pista:** Usa `break` para salir y un índice para simular inputs

# %%
# Escribe tu código aquí
# Simulamos las opciones que el usuario "ingresaría"
opciones_usuario = ["1", "2", "4", "3"]  # Última es salir
indice = 0

# Tu solución:

# %% [markdown]
# ### Ejercicio 14: Generador de Contraseñas con Validación 🔴
#
# Genera contraseñas aleatorias hasta encontrar una que cumpla los criterios:
# - Al menos 8 caracteres
# - Al menos un número
# - Al menos una letra mayúscula
# - Al menos una letra minúscula
#
# ```python
# import random
# import string
#
# # Conjunto de caracteres posibles
# caracteres = string.ascii_letters + string.digits
# ```
#
# 1. Usa un bucle `while` que genere contraseñas hasta encontrar una válida
# 2. Lleva un contador de intentos
# 3. Limita a máximo 100 intentos
#
# **Pista:** Usa `any()` para verificar condiciones

# %%
# Escribe tu código aquí
import random
import string

caracteres = string.ascii_letters + string.digits

# Tu solución:

# %% [markdown]
# ---
# ## Bloque 4: Control de Bucles (break, continue, else)

# %% [markdown]
# ### Ejercicio 15: Filtrado de Puertos con continue 🟢
#
# Dada una lista de puertos, procesa solo los que están en el rango 20-100:
# ```python
# puertos = [10, 22, 15, 80, 443, 50, 8080, 25, 110]
# ```
#
# 1. Recorre la lista con `for`
# 2. Si el puerto está fuera del rango 20-100, salta al siguiente con `continue`
# 3. Para los puertos válidos, imprime: `"Procesando puerto X"`
#
# **Pista:** Usa `continue` cuando `puerto < 20 or puerto > 100`

# %%
# Escribe tu código aquí
puertos = [10, 22, 15, 80, 443, 50, 8080, 25, 110]

# Tu solución:

# %% [markdown]
# ### Ejercicio 16: Búsqueda con else 🟡
#
# Busca si hay algún puerto vulnerable (21, 23, 445) en una lista:
# ```python
# puertos_abiertos = [22, 80, 443, 3306]
# puertos_vulnerables = [21, 23, 445]
# ```
#
# 1. Recorre `puertos_abiertos`
# 2. Si encuentras uno vulnerable, muestra una alerta y usa `break`
# 3. Si terminas el bucle sin encontrar ninguno, usa `else` para mostrar "No se encontraron puertos vulnerables"
#
# **Pista:** El `else` del `for` se ejecuta solo si no hubo `break`

# %%
# Escribe tu código aquí
puertos_abiertos = [22, 80, 443, 3306]
puertos_vulnerables = [21, 23, 445]

# Tu solución:

# %% [markdown]
# ### Ejercicio 17: Procesador de Logs con break y continue 🟡
#
# Procesa un log línea por línea:
# ```python
# log = [
#     "[INFO] Sistema iniciado",
#     "[DEBUG] Conectando a base de datos",
#     "[INFO] Conexión establecida",
#     "[ERROR] Fallo en autenticación",
#     "[DEBUG] Reintentando...",
#     "[CRITICAL] Sistema comprometido",
#     "[INFO] Sesión cerrada"
# ]
# ```
#
# Reglas:
# 1. Ignora líneas con `[DEBUG]` usando `continue`
# 2. Si encuentras `[CRITICAL]`, muestra alerta y termina con `break`
# 3. Para las demás, solo imprime la línea
#
# **Pista:** Usa `in` para verificar si contiene el texto

# %%
# Escribe tu código aquí
log = [
    "[INFO] Sistema iniciado",
    "[DEBUG] Conectando a base de datos",
    "[INFO] Conexión establecida",
    "[ERROR] Fallo en autenticación",
    "[DEBUG] Reintentando...",
    "[CRITICAL] Sistema comprometido",
    "[INFO] Sesión cerrada"
]

# Tu solución:

# %% [markdown]
# ### Ejercicio 18: Verificador de Números Primos 🔴
#
# Determina si un número es primo usando `for-else`:
#
# ```python
# numero = 29
# ```
#
# Un número es primo si solo es divisible por 1 y por sí mismo.
#
# 1. Verifica divisores desde 2 hasta la raíz cuadrada del número
# 2. Si encuentras un divisor, usa `break` e indica que no es primo
# 3. Si el bucle termina sin encontrar divisores, usa `else` para indicar que es primo
# 4. Casos especiales: números menores a 2 no son primos
#
# **Pista:** Usa `int(numero ** 0.5) + 1` como límite del rango

# %%
# Escribe tu código aquí
numero = 29

# Tu solución:

# %% [markdown]
# ### Ejercicio 19: Analizador de Intentos de Acceso 🔴
#
# Analiza una lista de intentos de acceso:
# ```python
# intentos = [
#     {"usuario": "admin", "exito": False},
#     {"usuario": "admin", "exito": False},
#     {"usuario": "root", "exito": False},
#     {"usuario": "admin", "exito": False},
#     {"usuario": "user", "exito": True},
#     {"usuario": "admin", "exito": False}
# ]
# ```
#
# Reglas:
# 1. Si el mismo usuario falla 3 veces consecutivas, emite alerta y para el análisis
# 2. Si hay un acceso exitoso, reinicia el contador de fallos
# 3. Usa `break` para detener si se detecta ataque
# 4. Usa `else` para indicar "No se detectaron patrones de ataque"
#
# **Pista:** Usa variables para rastrear el usuario anterior y contador de fallos

# %%
# Escribe tu código aquí
intentos = [
    {"usuario": "admin", "exito": False},
    {"usuario": "admin", "exito": False},
    {"usuario": "root", "exito": False},
    {"usuario": "admin", "exito": False},
    {"usuario": "user", "exito": True},
    {"usuario": "admin", "exito": False}
]

# Tu solución:

# %% [markdown]
# ### Ejercicio 20: Validador de Contraseña Complejo 🔴
#
# Valida una contraseña según múltiples reglas:
# ```python
# password = "MyP@ssw0rd123"
# ```
#
# Reglas:
# 1. Mínimo 8 caracteres
# 2. Al menos una mayúscula
# 3. Al menos una minúscula
# 4. Al menos un número
# 5. Al menos un carácter especial (!@#$%^&*)
# 6. No debe contener la palabra "password" (case insensitive)
#
# Implementa:
# - Usa un bucle `for` para verificar cada carácter
# - Usa variables booleanas para rastrear qué reglas se cumplen
# - Si encuentra "password" en cualquier parte, usa `break` y rechaza
# - Al final, verifica todas las condiciones
#
# **Pista:** Usa `string.punctuation` para caracteres especiales

# %%
# Escribe tu código aquí
import string

password = "MyP@ssw0rd123"

# Tu solución:

# %% [markdown]
# ---
# ## Bloque 5: Funciones Básicas

# %% [markdown]
# ### Ejercicio 21: Mi Primera Función 🟢
#
# Crea una función llamada `escanear_puerto()` que:
# 1. Reciba dos parámetros: `ip` y `puerto`
# 2. Imprima: `"[*] Escaneando {ip}:{puerto}..."`
# 3. Retorne siempre `True` (simula que está abierto)
#
# Luego:
# - Llama a la función con `"192.168.1.1"` y puerto `22`
# - Guarda el resultado en una variable
# - Imprime el resultado
#
# **Pista:** Usa `def nombre_funcion(parametros):`

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 22: Función Validadora de IP 🟢
#
# Crea una función `validar_ip(ip)` que verifique si una IP es válida:
# 1. Divide la IP por puntos
# 2. Verifica que tenga exactamente 4 octetos
# 3. Verifica que cada octeto sea un número entre 0 y 255
# 4. Retorna `True` si es válida, `False` en caso contrario
#
# Pruébala con:
# ```python
# ips = ["192.168.1.1", "256.1.1.1", "192.168.1", "10.0.0.1"]
# ```
#
# **Pista:** Usa `.split()`, `.isdigit()` y conversión a `int()`

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 23: Múltiples Valores de Retorno 🟡
#
# Crea una función `analizar_puerto(puerto)` que retorne una tupla con:
# 1. Si es puerto privilegiado (< 1024)
# 2. El nombre del servicio si es conocido, o "Desconocido"
# 3. El tipo de puerto: "sistema", "registrado" o "dinámico"
#
# Servicios conocidos:
# ```python
# servicios = {21: "FTP", 22: "SSH", 80: "HTTP", 443: "HTTPS", 3306: "MySQL"}
# ```
#
# Tipos:
# - Sistema: 0-1023
# - Registrado: 1024-49151
# - Dinámico: 49152-65535
#
# Prueba con puertos: 22, 8080, 50000
#
# **Pista:** Retorna múltiples valores separados por comas

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 24: Función con Parámetros por Defecto 🟡
#
# Crea una función `escanear_red()` con los siguientes parámetros:
# ```python
# def escanear_red(red, puerto=80, timeout=5, verbose=False):
# ```
#
# La función debe:
# 1. Imprimir información del escaneo
# 2. Si `verbose=True`, mostrar más detalles
# 3. Retornar un diccionario con: `{"red": ..., "puerto": ..., "timeout": ...}`
#
# Llámala de estas formas:
# - Solo con red: `escanear_red("192.168.1.0/24")`
# - Cambiando puerto: `escanear_red("192.168.1.0/24", 443)`
# - Con verbose: `escanear_red("192.168.1.0/24", verbose=True)`
# - Todos los parámetros: `escanear_red("192.168.1.0/24", 22, 10, True)`
#
# **Pista:** Los parámetros con default van después de los obligatorios

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 25: Función con *args 🟡
#
# Crea una función `escanear_puertos(ip, *puertos)` que:
# 1. Reciba una IP y un número variable de puertos
# 2. Para cada puerto, simule un escaneo
# 3. Retorne una lista con los puertos "abiertos" (simula que los pares están abiertos)
#
# Ejemplo de uso:
# ```python
# resultado = escanear_puertos("192.168.1.1", 22, 80, 443, 8080)
# # Debe retornar [22, 80, 8080] (los pares)
# ```
#
# **Pista:** `*puertos` captura todos los argumentos adicionales como tupla

# %%
# Escribe tu código aquí

# %% [markdown]
# ---
# ## Bloque 6: Funciones Avanzadas

# %% [markdown]
# ### Ejercicio 26: Función con **kwargs 🔴
#
# Crea una función `configurar_herramienta(**opciones)` que:
# 1. Acepte un número variable de opciones como keyword arguments
# 2. Tenga valores por defecto para: `timeout=10`, `verbose=False`, `output="json"`
# 3. Mezcle las opciones recibidas con los defaults (los recibidos tienen prioridad)
# 4. Imprima la configuración final
# 5. Retorne el diccionario de configuración completo
#
# Ejemplo de uso:
# ```python
# config = configurar_herramienta(timeout=30, threads=10, verbose=True)
# ```
#
# **Pista:** Usa `.get()` en diccionarios para manejar valores por defecto

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 27: Función Combinada (args + kwargs) 🔴
#
# Crea una función `ejecutar_herramienta(nombre, *objetivos, **opciones)` que:
# 1. `nombre`: nombre de la herramienta (obligatorio)
# 2. `*objetivos`: lista de IPs/hosts a escanear
# 3. `**opciones`: opciones de configuración
#
# La función debe:
# - Imprimir el nombre de la herramienta
# - Listar todos los objetivos
# - Mostrar las opciones configuradas
# - Retornar un diccionario con toda la información
#
# Ejemplo:
# ```python
# resultado = ejecutar_herramienta(
#     "nmap",
#     "192.168.1.1",
#     "192.168.1.2",
#     "google.com",
#     puertos="1-1000",
#     velocidad="rapido",
#     output="xml"
# )
# ```
#
# **Pista:** El orden es importante: `(posicionales, *args, **kwargs)`

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 28: Generador de Reportes 🔴
#
# Crea una función `generar_reporte(titulo, datos, **formato)` que:
# 1. Reciba un título y un diccionario de datos
# 2. Acepte opciones de formato: `ancho=50`, `separador="="`, `alineacion="centro"`
# 3. Genere un reporte formateado con:
#    - Encabezado con el título
#    - Línea separadora
#    - Cada dato del diccionario en formato `clave: valor`
#    - Línea separadora final
#
# Ejemplo:
# ```python
# datos_escaneo = {
#     "IP": "192.168.1.100",
#     "Puertos abiertos": 5,
#     "Sistema": "Linux",
#     "Vulnerabilidades": 2
# }
# reporte = generar_reporte("REPORTE DE ESCANEO", datos_escaneo, ancho=60)
# ```
#
# **Pista:** Usa métodos de string como `.center()`, `.ljust()`, `.rjust()`

# %%
# Escribe tu código aquí

# %% [markdown]
# ---
# ## Bloque 7: Scope y Documentación

# %% [markdown]
# ### Ejercicio 29: Scope de Variables 🟡
#
# Analiza y corrige este código:
#
# ```python
# contador = 0
#
# def incrementar():
#     contador = contador + 1  # ¿Qué problema hay aquí?
#     return contador
#
# def incrementar_global():
#     # Corrige esta función para que modifique la variable global
#     pass
#
# def resetear():
#     # Esta función debe poner el contador global a 0
#     pass
# ```
#
# Tareas:
# 1. Explica por qué `incrementar()` da error
# 2. Corrige `incrementar_global()` usando `global`
# 3. Implementa `resetear()`
# 4. Crea una versión alternativa que use parámetros y retorno en lugar de global
#
# **Pista:** Usa la palabra clave `global` para modificar variables globales

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 30: Documentación con Docstrings 🟡
#
# Crea una función completamente documentada `calcular_subnet()` que:
#
# ```python
# def calcular_subnet(ip, mascara):
#     """
#     [Escribe aquí la documentación completa]
#     """
#     pass
# ```
#
# La documentación debe incluir:
# 1. Descripción breve (una línea)
# 2. Descripción detallada
# 3. Args: con tipo y descripción
# 4. Returns: qué retorna
# 5. Raises: qué excepciones puede lanzar
# 6. Examples: al menos 2 ejemplos de uso
#
# Implementación simple:
# - Retorna un diccionario con: `{"red": ip, "mascara": mascara, "bits": numero_de_bits}`
# - Si la máscara no es válida (0-32), lanza `ValueError`
#
# **Pista:** Sigue el formato Google Style Docstring

# %%
# Escribe tu código aquí

# %% [markdown]
# ---
# ## Bloque 8: Ejercicios Integradores

# %% [markdown]
# ### Ejercicio 31: Sistema de Autenticación Completo 🔴
#
# Crea un sistema de autenticación con las siguientes funciones:
#
# ```python
# # Base de datos simulada
# usuarios = {
#     "admin": {"password": "admin123", "intentos": 0, "bloqueado": False},
#     "user": {"password": "user456", "intentos": 0, "bloqueado": False}
# }
# ```
#
# Implementa:
# 1. `validar_credenciales(usuario, password)`: verifica si son correctas
# 2. `intentar_login(usuario, password)`: gestiona intentos (máximo 3)
# 3. `bloquear_usuario(usuario)`: marca usuario como bloqueado
# 4. `resetear_intentos(usuario)`: reinicia contador de intentos
# 5. `esta_bloqueado(usuario)`: verifica si está bloqueado
#
# Reglas:
# - Después de 3 intentos fallidos, bloquear usuario
# - Login exitoso reinicia intentos
# - Usuario bloqueado no puede intentar login
#
# **Pista:** Modifica el diccionario global o pásalo como parámetro

# %%
# Escribe tu código aquí
usuarios = {
    "admin": {"password": "admin123", "intentos": 0, "bloqueado": False},
    "user": {"password": "user456", "intentos": 0, "bloqueado": False}
}

# Tu solución:

# %% [markdown]
# ### Ejercicio 32: Analizador de Logs Avanzado 🔴
#
# Crea un sistema de análisis de logs con estas funciones:
#
# ```python
# def parsear_linea_log(linea):
#     """
#     Parsea una línea de log y extrae: timestamp, nivel, mensaje
#     Formato: "[2025-01-30 10:30:15] [ERROR] Mensaje del error"
#     """
#     pass
#
# def filtrar_logs(logs, nivel=None, palabra_clave=None):
#     """
#     Filtra logs por nivel y/o palabra clave
#     """
#     pass
#
# def estadisticas_logs(logs):
#     """
#     Retorna diccionario con estadísticas:
#     - Total de logs
#     - Logs por nivel (INFO, WARNING, ERROR, CRITICAL)
#     - Nivel más frecuente
#     """
#     pass
#
# def generar_reporte_logs(logs, **opciones):
#     """
#     Genera reporte formateado con estadísticas y logs filtrados
#     """
#     pass
# ```
#
# Datos de prueba:
# ```python
# logs = [
#     "[2025-01-30 10:30:15] [INFO] Sistema iniciado",
#     "[2025-01-30 10:31:20] [ERROR] Fallo en conexión",
#     "[2025-01-30 10:32:10] [WARNING] Memoria baja",
#     "[2025-01-30 10:33:45] [ERROR] Timeout en base de datos",
#     "[2025-01-30 10:34:00] [CRITICAL] Sistema comprometido",
#     "[2025-01-30 10:35:12] [INFO] Sesión cerrada"
# ]
# ```
#
# **Desafío:** Implementa todas las funciones y genera un reporte completo

# %%
# Escribe tu código aquí
logs = [
    "[2025-01-30 10:30:15] [INFO] Sistema iniciado",
    "[2025-01-30 10:31:20] [ERROR] Fallo en conexión",
    "[2025-01-30 10:32:10] [WARNING] Memoria baja",
    "[2025-01-30 10:33:45] [ERROR] Timeout en base de datos",
    "[2025-01-30 10:34:00] [CRITICAL] Sistema comprometido",
    "[2025-01-30 10:35:12] [INFO] Sesión cerrada"
]

# Tu solución:

# %% [markdown]
# ### Ejercicio 33: Calculadora de Subredes 🔴
#
# Crea un conjunto de funciones para trabajar con subredes:
#
# ```python
# def ip_a_binario(ip):
#     """
#     Convierte IP a representación binaria
#     "192.168.1.1" -> "11000000.10101000.00000001.00000001"
#     """
#     pass
#
# def ip_a_decimal(ip):
#     """
#     Convierte IP a número decimal
#     "192.168.1.1" -> 3232235777
#     """
#     pass
#
# def calcular_red(ip, cidr):
#     """
#     Calcula dirección de red dada una IP y CIDR
#     calcular_red("192.168.1.100", 24) -> "192.168.1.0"
#     """
#     pass
#
# def calcular_broadcast(ip, cidr):
#     """
#     Calcula dirección de broadcast
#     calcular_broadcast("192.168.1.0", 24) -> "192.168.1.255"
#     """
#     pass
#
# def rango_hosts(ip, cidr):
#     """
#     Retorna primer y última IP utilizable
#     rango_hosts("192.168.1.0", 24) -> ("192.168.1.1", "192.168.1.254")
#     """
#     pass
#
# def info_subred(ip, cidr):
#     """
#     Retorna diccionario completo con toda la información de la subred
#     """
#     pass
# ```
#
# Prueba con: `"192.168.1.100"`, CIDR `24`
#
# **Pista:** Usa operaciones bitwise (`&`, `|`, `~`, `<<`, `>>`)

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 34: Simulador de Escaneo de Red Completo 🔴
#
# Crea un simulador completo de escaneo de red que integre todo lo aprendido:
#
# ```python
# import random
#
# def generar_hosts(red, cidr):
#     """
#     Genera lista de todas las IPs en la subred (simulado)
#     """
#     pass
#
# def esta_activo(ip, timeout=1):
#     """
#     Simula ping - retorna True aleatoriamente (30% probabilidad)
#     """
#     pass
#
# def escanear_puerto(ip, puerto, timeout=1):
#     """
#     Simula escaneo de puerto - retorna estado aleatorio
#     """
#     pass
#
# def escanear_puertos_comunes(ip, *puertos, timeout=1, verbose=False):
#     """
#     Escanea lista de puertos en una IP
#     Retorna lista de puertos abiertos
#     """
#     pass
#
# def escanear_red_completa(red, cidr, puertos=[21,22,80,443], **opciones):
#     """
#     Escaneo completo de red:
#     1. Descubre hosts activos
#     2. Escanea puertos en hosts activos
#     3. Genera reporte
#
#     Retorna diccionario con resultados
#     """
#     pass
#
# def generar_reporte_escaneo(resultados, formato="texto"):
#     """
#     Genera reporte formateado del escaneo
#     formato puede ser: "texto", "json", "tabla"
#     """
#     pass
# ```
#
# Ejecuta un escaneo completo:
# ```python
# resultado = escanear_red_completa(
#     "192.168.1.0",
#     24,
#     puertos=[22, 80, 443, 3306, 8080],
#     timeout=2,
#     verbose=True
# )
#
# reporte = generar_reporte_escaneo(resultado, formato="tabla")
# print(reporte)
# ```
#
# **Desafío Final:** Implementa el sistema completo con todas las funciones documentadas

# %%
# Escribe tu código aquí
import random

# Tu solución:
