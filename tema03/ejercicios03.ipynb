# %% [markdown]
# # Sesión 3: Ejercicios Prácticos
# ## Archivos, Expresiones Regulares y Sistema Operativo
#
# **Nivel de dificultad:**
# - 🟢 Básico
# - 🟡 Intermedio
# - 🔴 Avanzado

# %% [markdown]
# ---
# ## BLOQUE 1: Manejo de Archivos

# %% [markdown]
# ### Ejercicio 1: Crear Log de Seguridad 🟢
#
# Crea un archivo llamado `security.log` con las siguientes líneas:
# ```
# [INFO] Sistema iniciado
# [WARNING] Intento de acceso desde IP desconocida
# [ERROR] Contraseña incorrecta
# [INFO] Sesión cerrada
# ```
#
# 1. Escribe estas líneas en el archivo
# 2. Lee el archivo completo e imprímelo
# 3. Cuenta cuántas líneas tiene
# 4. Imprime solo las líneas que contengan "ERROR"
#
# **Pista:** Usa `with open()` y métodos de strings

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 2: Análisis de Log 🟢
#
# Dado el siguiente log:
# ```python
# log = """2024-01-15 10:00:01 [INFO] Usuario admin login exitoso
# 2024-01-15 10:05:23 [WARNING] Intento fallido desde 192.168.1.50
# 2024-01-15 10:10:45 [ERROR] Conexión perdida
# 2024-01-15 10:15:12 [INFO] Sistema operando normalmente
# 2024-01-15 10:20:33 [ERROR] Base de datos no responde"""
# ```
#
# 1. Escribe el log en un archivo `system.log`
# 2. Lee el archivo línea por línea
# 3. Cuenta cuántos mensajes de cada tipo hay (INFO, WARNING, ERROR)
# 4. Crea un nuevo archivo `errors.log` solo con las líneas de ERROR
#
# **Pista:** Usa `.count()` o un diccionario para contar tipos

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 3: Append de Eventos 🟢
#
# Tienes un archivo `eventos.txt` con contenido inicial:
# ```
# Evento 1: Sistema iniciado
# Evento 2: Usuario conectado
# ```
#
# 1. Crea el archivo con ese contenido
# 2. Añade 3 eventos más usando modo append:
#    - "Evento 3: Escaneo completado"
#    - "Evento 4: Vulnerabilidad detectada"
#    - "Evento 5: Reporte generado"
# 3. Lee y muestra todo el contenido
# 4. Imprime el número total de líneas
#
# **Pista:** Usa modo `'a'` para append

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 4: Wordlist Generator 🟡
#
# Crea una función `generar_wordlist(archivo, passwords)` que:
# - Reciba un nombre de archivo y una lista de contraseñas
# - Escriba cada contraseña en una línea del archivo
# - Retorne el número de contraseñas escritas
#
# Pruébala con:
# ```python
# passwords = ["admin", "password", "123456", "qwerty", "letmein"]
# ```
#
# Luego:
# 1. Genera el archivo `wordlist.txt`
# 2. Lee el archivo y verifica que todas las contraseñas están ahí
# 3. Añade 5 contraseñas más al archivo existente
#
# **Pista:** Usa `\n` para saltos de línea

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 5: Filtro de IPs 🟡
#
# Dado un archivo `access.log` con el siguiente contenido:
# ```
# 192.168.1.1 - GET /index.html
# 10.0.0.50 - POST /login
# 192.168.1.100 - GET /admin
# 203.0.113.42 - GET /
# 192.168.1.1 - GET /logout
# ```
#
# 1. Crea el archivo con ese contenido
# 2. Lee el archivo y extrae todas las IPs únicas
# 3. Crea un nuevo archivo `ips_unicas.txt` con una IP por línea
# 4. Cuenta cuántas veces aparece cada IP
#
# **Pista:** Usa `split()` y un conjunto (set) para IPs únicas

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 6: CSV de Escaneo 🟡
#
# Usa el módulo `csv` para crear un archivo `scan_results.csv` con:
# ```
# IP,Puerto,Estado,Servicio
# 192.168.1.1,22,open,SSH
# 192.168.1.1,80,open,HTTP
# 192.168.1.1,443,closed,HTTPS
# 192.168.1.2,22,open,SSH
# 192.168.1.2,3306,filtered,MySQL
# ```
#
# 1. Crea el archivo usando `csv.writer` o `csv.DictWriter`
# 2. Lee el archivo e imprime solo los puertos abiertos
# 3. Cuenta cuántos puertos hay por cada estado (open, closed, filtered)
# 4. Crea un nuevo CSV `puertos_abiertos.csv` solo con estado "open"
#
# **Pista:** Importa `import csv` al inicio

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 7: JSON de Vulnerabilidades 🟡
#
# Crea un diccionario con información de vulnerabilidades:
# ```python
# vulnerabilidades = {
#     "host": "192.168.1.10",
#     "fecha_escaneo": "2024-01-15",
#     "vulnerabilidades": [
#         {
#             "cve": "CVE-2024-0001",
#             "severidad": "alta",
#             "descripcion": "Buffer overflow en servicio SSH"
#         },
#         {
#             "cve": "CVE-2024-0002",
#             "severidad": "media",
#             "descripcion": "Cross-site scripting"
#         }
#     ]
# }
# ```
#
# 1. Guarda el diccionario en `vulns.json` con formato legible (indent=4)
# 2. Lee el archivo JSON
# 3. Imprime solo las vulnerabilidades de severidad "alta"
# 4. Añade una vulnerabilidad más y guarda el archivo actualizado
#
# **Pista:** Usa `json.dump()` y `json.load()`

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 8: Identificador de Archivos 🔴
#
# Crea una función `identificar_archivo(ruta)` que:
# - Lea los primeros 8 bytes del archivo
# - Identifique el tipo basándose en magic bytes:
#   - PNG: `\x89PNG`
#   - JPEG: `\xff\xd8\xff`
#   - PDF: `%PDF`
#   - ZIP: `PK\x03\x04`
# - Retorne el tipo detectado o "Desconocido"
#
# Prueba con:
# 1. Crear archivos simulados con esos magic bytes
# 2. Identificar cada uno
# 3. Crear un reporte en texto con los resultados
#
# **Pista:** Abre en modo `'rb'` (binario) y usa `.startswith()`

# %%
# Escribe tu código aquí

# %% [markdown]
# ---
# ## BLOQUE 2: Expresiones Regulares - Fundamentos

# %% [markdown]
# ### Ejercicio 9: Buscar IPs 🟢
#
# Dado el texto:
# ```python
# texto = "El servidor 192.168.1.1 se conectó con 10.0.0.50 y 172.16.0.1"
# ```
#
# 1. Usa `re.findall()` para extraer todas las IPs
# 2. Usa `re.search()` para encontrar la primera IP
# 3. Imprime la posición (start, end) de cada IP con `re.finditer()`
# 4. Reemplaza todas las IPs por "[REDACTED]" con `re.sub()`
#
# **Pista:** Patrón simple: `r'\d+\.\d+\.\d+\.\d+'`

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 10: Validar Email 🟢
#
# Crea una función `validar_email(email)` que:
# - Use regex para verificar si un email es válido
# - Retorne `True` si es válido, `False` si no
#
# Patrón básico: `r'^[\w.-]+@[\w.-]+\.\w+$'`
#
# Prueba con:
# ```python
# emails = [
#     "usuario@ejemplo.com",      # Válido
#     "admin@empresa.net",        # Válido
#     "invalido@",                # Inválido
#     "@sin-usuario.com",         # Inválido
#     "test.user@sub.domain.org"  # Válido
# ]
# ```
#
# **Pista:** Usa `re.match()` con el patrón

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 11: Extraer Dominios 🟢
#
# Dado el texto:
# ```python
# texto = """Visita www.ejemplo.com o https://secure.bank.com
# También puedes ir a mail.google.com y test.subdomain.example.org"""
# ```
#
# 1. Extrae todos los dominios (con o sin www/https)
# 2. Elimina duplicados
# 3. Imprime cada dominio único
# 4. Cuenta cuántos dominios hay
#
# **Pista:** Patrón: `r'(?:[\w-]+\.)+[a-z]{2,}'`

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 12: Parser de Log con Grupos 🟡
#
# Dado un log:
# ```python
# log = "192.168.1.1 - GET /index.html - 200"
# ```
#
# 1. Usa regex con grupos capturadores para extraer:
#    - IP
#    - Método HTTP (GET)
#    - Ruta (/index.html)
#    - Código de respuesta (200)
# 2. Usa `.group(1)`, `.group(2)`, etc. para acceder a cada parte
# 3. Almacena los datos en un diccionario
#
# **Pista:** Patrón: `r'(\S+) - (\w+) (\S+) - (\d+)'`

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 13: Validar Password 🟡
#
# Crea una función `validar_password(password)` que verifique:
# - Mínimo 8 caracteres
# - Al menos una mayúscula
# - Al menos una minúscula
# - Al menos un dígito
# - Al menos un carácter especial (@#$%)
#
# Usa múltiples patrones regex con `re.search()`:
# ```python
# tiene_mayuscula = re.search(r'[A-Z]', password)
# tiene_minuscula = re.search(r'[a-z]', password)
# # etc...
# ```
#
# Prueba con:
# ```python
# passwords = ["Abc123@x", "debil", "SinNumero@", "Valid123@Pass"]
# ```

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 14: Extraer MAC Addresses 🟡
#
# Dado el texto:
# ```python
# texto = """Dispositivo 1: 00:1A:2B:3C:4D:5E
# Dispositivo 2: AA-BB-CC-DD-EE-FF
# Dispositivo 3: 112233445566"""
# ```
#
# 1. Crea un patrón que detecte MACs en los 3 formatos (`:`, `-`, sin separador)
# 2. Extrae todas las MACs
# 3. Normalízalas todas al formato `XX:XX:XX:XX:XX:XX`
# 4. Imprime las MACs normalizadas
#
# **Pista:** Patrón: `r'[0-9A-Fa-f]{2}[:-]?[0-9A-Fa-f]{2}...'`

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 15: Compilar Patrones 🟡
#
# Crea patrones compilados para:
# - IPs
# - Emails
# - URLs
# - Números de teléfono (formato +XX XXX XXX XXXX)
#
# Luego procesa este texto:
# ```python
# texto = """Contacto: admin@empresa.com
# Teléfono: +34 123 456 7890
# Sitio web: https://www.empresa.com
# IP del servidor: 203.0.113.42"""
# ```
#
# Extrae e imprime cada tipo de dato encontrado.
#
# **Pista:** Usa `re.compile()` para cada patrón

# %%
# Escribe tu código aquí

# %% [markdown]
# ---
# ## BLOQUE 2 (Continuación): Expresiones Regulares Avanzadas

# %% [markdown]
# ### Ejercicio 16: Extractor de CVEs 🟢
#
# Dado un reporte de seguridad:
# ```python
# reporte = """Se detectaron las siguientes vulnerabilidades:
# - CVE-2024-1234: Buffer overflow crítico
# - CVE-2023-9999: XSS en formulario
# - CVE-2024-0001: SQL injection
# El CVE-2022-5678 ya fue parcheado."""
# ```
#
# 1. Extrae todos los CVEs
# 2. Ordénalos por año (más reciente primero)
# 3. Agrúpalos por año
# 4. Imprime un resumen con el formato:
#    ```
#    Año 2024: 2 CVEs
#    Año 2023: 1 CVE
#    Año 2022: 1 CVE
#    ```
#
# **Pista:** Patrón CVE: `r'CVE-\d{4}-\d{4,}'`

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 17: Parser de User-Agent 🟡
#
# Dado un User-Agent:
# ```python
# ua = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
# ```
#
# Usa regex para extraer:
# 1. El sistema operativo (Windows NT 10.0)
# 2. La arquitectura (Win64; x64)
# 3. El navegador (Chrome)
# 4. La versión del navegador (91.0.4472.124)
#
# Crea un diccionario con toda la información extraída.
#
# **Pista:** Usa grupos con nombres: `(?P<nombre>...)`

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 18: Detectar Hashes 🟡
#
# Dado un texto con diferentes tipos de hash:
# ```python
# texto = """MD5: 5d41402abc4b2a76b9719d911017c592
# SHA1: aaf4c61ddcc5e8a2dabede0f3b482cd9aea9434d
# SHA256: 2c26b46b68ffc68ff99b453c1d30413413422d706483bfa0f98a5e886266e7ae
# Otro hash MD5: 098f6bcd4621d373cade4e832627b4f6"""
# ```
#
# 1. Crea patrones para detectar:
#    - MD5 (32 caracteres hex)
#    - SHA1 (40 caracteres hex)
#    - SHA256 (64 caracteres hex)
# 2. Extrae todos los hashes
# 3. Clasifícalos por tipo
# 4. Imprime un reporte con cada tipo y cuántos encontraste
#
# **Pista:** Usa `\b` para límites de palabra

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 19: Limpiar Código SQL Injection 🟡
#
# Dado un log con intentos de SQL injection:
# ```python
# logs = [
#     "username=admin' OR '1'='1",
#     "id=1; DROP TABLE users--",
#     "search=' UNION SELECT * FROM passwords--",
#     "user=normal_user"
# ]
# ```
#
# 1. Usa regex para detectar patrones sospechosos:
#    - Comillas simples seguidas de OR
#    - Palabras clave SQL (DROP, UNION, SELECT)
#    - Comentarios SQL (--)
# 2. Marca cada log como "Sospechoso" o "Normal"
# 3. Crea una lista solo con los intentos maliciosos
# 4. Imprime un reporte de seguridad
#
# **Pista:** Usa `re.IGNORECASE` para detectar mayúsculas y minúsculas

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 20: Extractor de IoCs Completo 🔴
#
# Crea una función `extraer_iocs(texto)` que extraiga todos los Indicadores de Compromiso:
# - IPs (IPv4 e IPv6)
# - Dominios
# - URLs
# - Emails
# - Hashes (MD5, SHA1, SHA256)
# - CVEs
#
# Prueba con este reporte:
# ```python
# reporte = """Análisis de malware:
# C2 Server: 198.51.100.42 (malicious.evil-domain.com)
# Hash MD5: d41d8cd98f00b204e9800998ecf8427e
# Email de phishing: attacker@fake-bank.com
# URL maliciosa: http://phishing.bad-site.net/login.php
# Explota CVE-2024-1234
# IPv6: 2001:0db8:85a3:0000:0000:8a2e:0370:7334"""
# ```
#
# La función debe retornar un diccionario con todos los IoCs clasificados.
#
# **Pista:** Usa los patrones del contenido proporcionado

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 21: Ofuscador de Datos Sensibles 🔴
#
# Crea una función `ofuscar_datos(texto)` que reemplace:
# - Tarjetas de crédito (XXXX-XXXX-XXXX-1234 → XXXX-XXXX-XXXX-[REDACTED])
# - IPs (192.168.1.1 → [IP-REDACTED])
# - Emails (user@domain.com → [EMAIL-REDACTED])
# - Números de teléfono (+34 123 456 789 → [PHONE-REDACTED])
#
# Prueba con:
# ```python
# texto = """Cliente: juan@empresa.com
# Teléfono: +34 666 777 888
# Tarjeta: 4532-1234-5678-9010
# IP: 192.168.1.50"""
# ```
#
# La función debe retornar el texto ofuscado y un diccionario con los datos originales.
#
# **Pista:** Usa `re.sub()` con funciones de reemplazo

# %%
# Escribe tu código aquí

# %% [markdown]
# ---
# ## BLOQUE 3: Módulo os

# %% [markdown]
# ### Ejercicio 22: Información del Sistema 🟢
#
# Usa el módulo `os` para:
# 1. Imprimir el nombre del sistema operativo (`os.name`)
# 2. Obtener el directorio actual (`os.getcwd()`)
# 3. Listar todos los archivos del directorio actual
# 4. Separar archivos de directorios
# 5. Contar cuántos archivos y directorios hay
#
# Imprime un reporte formateado con toda la información.
#
# **Pista:** Usa `os.path.isfile()` y `os.path.isdir()`

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 23: Crear Estructura de Directorios 🟢
#
# Crea la siguiente estructura de directorios para un proyecto:
# ```
# proyecto/
# ├── src/
# ├── tests/
# ├── docs/
# └── logs/
#     ├── access/
#     └── errors/
# ```
#
# 1. Usa `os.makedirs()` con `exist_ok=True`
# 2. Verifica que todos los directorios fueron creados
# 3. Usa `os.walk()` para mostrar la estructura
# 4. Crea un archivo `README.txt` en el directorio raíz
#
# **Pista:** Usa `os.path.join()` para rutas portables

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 24: Búsqueda de Archivos 🟡
#
# Crea una función `buscar_archivos(directorio, extension)` que:
# - Busque recursivamente archivos con una extensión específica
# - Retorne una lista con las rutas completas
#
# Luego:
# 1. Busca todos los archivos `.txt` en el directorio actual
# 2. Busca todos los archivos `.py`
# 3. Para cada archivo encontrado, muestra:
#    - Nombre
#    - Ruta completa
#    - Tamaño en bytes
#
# **Pista:** Usa `os.walk()` para recorrer subdirectorios

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 25: Variables de Entorno 🟡
#
# Trabajando con variables de entorno:
# 1. Lista todas las variables de entorno disponibles
# 2. Obtén las variables:
#    - PATH
#    - HOME (o USERPROFILE en Windows)
#    - USER (o USERNAME en Windows)
# 3. Crea una nueva variable `MI_SECRETO` con un valor
# 4. Verifica que la variable fue creada
# 5. Simula buscar variables sensibles (API_KEY, PASSWORD, SECRET)
#
# Imprime un reporte de seguridad indicando si encontraste variables sensibles.
#
# **Pista:** Usa `os.environ.get()` para acceso seguro

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 26: Manipulación de Rutas 🟡
#
# Dada una ruta completa:
# ```python
# ruta = "/home/usuario/documentos/proyecto/codigo/main.py"
# ```
#
# Usa `os.path` para extraer:
# 1. El nombre del archivo (`basename`)
# 2. El directorio padre (`dirname`)
# 3. La extensión del archivo (`splitext`)
# 4. Divide la ruta en todas sus partes
# 5. Construye una nueva ruta uniendo: `"proyecto"`, `"backup"`, `"main_backup.py"`
# 6. Convierte la ruta a absoluta
#
# **Pista:** Explora `os.path.split()`, `os.path.join()`, `os.path.abspath()`

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 27: Árbol de Directorios 🔴
#
# Crea una función `mostrar_arbol(directorio, nivel=0)` que:
# - Muestre la estructura de directorios en formato árbol
# - Use indentación para mostrar niveles
# - Marque archivos y directorios de forma diferente
#
# Ejemplo de salida:
# ```
# proyecto/
#   ├── src/
#   │   ├── main.py
#   │   └── utils.py
#   ├── tests/
#   │   └── test_main.py
#   └── README.txt
# ```
#
# Bonus: Añade el tamaño de cada archivo.
#
# **Pista:** Usa recursión y `os.walk()` o `os.listdir()`

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 28: Limpieza de Archivos Temporales 🔴
#
# Crea una función `limpiar_temporales(directorio, extensiones, dias=7)` que:
# - Busque archivos con las extensiones especificadas
# - Que tengan más de X días de antigüedad
# - Liste los archivos que serían eliminados
# - Opcionalmente los elimine (con confirmación)
#
# Prueba con:
# ```python
# # Buscar archivos .tmp, .log, .bak más antiguos de 7 días
# limpiar_temporales(".", [".tmp", ".log", ".bak"], dias=7)
# ```
#
# **Pista:** Usa `os.path.getmtime()` y `time.time()` para fechas
#
# **ADVERTENCIA:** No elimines archivos reales sin verificar

# %%
# Escribe tu código aquí

# %% [markdown]
# ---
# ## BLOQUE 4: Módulo subprocess

# %% [markdown]
# ### Ejercicio 29: Información del Sistema con Comandos 🟢
#
# Usa `subprocess` para ejecutar comandos del sistema:
#
# **En Windows:**
# - `systeminfo` → información del sistema
# - `ipconfig` → configuración de red
#
# **En Linux/Mac:**
# - `uname -a` → información del sistema
# - `ifconfig` o `ip addr` → configuración de red
#
# 1. Detecta el SO automáticamente
# 2. Ejecuta el comando apropiado
# 3. Captura la salida
# 4. Extrae información relevante usando regex
#
# **Pista:** Usa `subprocess.run()` con `capture_output=True`

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 30: Monitor de Procesos 🟡
#
# Crea un script que liste los procesos en ejecución:
#
# **Windows:** `tasklist`
# **Linux/Mac:** `ps aux`
#
# 1. Ejecuta el comando apropiado
# 2. Parsea la salida para extraer:
#    - Nombre del proceso
#    - PID
#    - Uso de memoria (si está disponible)
# 3. Ordena por uso de memoria (descendente)
# 4. Muestra los 10 procesos que más memoria consumen
#
# **Pista:** Usa `stdout.decode()` y procesa línea por línea

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 31: Ping Scanner 🟡
#
# Crea una función `ping(host)` que:
# - Use el comando `ping` del sistema
# - Envíe 4 paquetes (Windows: `-n 4`, Linux/Mac: `-c 4`)
# - Determine si el host está activo
# - Extraiga el tiempo de respuesta promedio
#
# Prueba con:
# ```python
# hosts = ["google.com", "8.8.8.8", "192.168.1.1", "localhost"]
# ```
#
# Imprime un reporte:
# ```
# google.com → ACTIVO (tiempo: 15ms)
# 8.8.8.8 → ACTIVO (tiempo: 20ms)
# 192.168.1.1 → INACTIVO
# localhost → ACTIVO (tiempo: 1ms)
# ```
#
# **Pista:** Verifica `returncode` y usa regex para extraer tiempos

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 32: Port Scanner Básico 🔴
#
# Crea un scanner de puertos usando `netstat` o comandos similares:
#
# **Windows:** `netstat -ano`
# **Linux:** `netstat -tuln` o `ss -tuln`
#
# 1. Ejecuta el comando apropiado
# 2. Parsea la salida para extraer:
#    - Puertos abiertos
#    - Protocolo (TCP/UDP)
#    - Estado de conexión
# 3. Filtra solo puertos LISTENING
# 4. Agrupa por rango de puertos:
#    - Puertos privilegiados (1-1023)
#    - Puertos registrados (1024-49151)
#    - Puertos dinámicos (49152-65535)
#
# **Pista:** Usa regex para extraer números de puerto

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 33: Ejecutar Scripts con Timeout 🔴
#
# Crea una función `ejecutar_con_timeout(comando, timeout=5)` que:
# - Ejecute un comando con límite de tiempo
# - Si excede el timeout, termine el proceso
# - Capture tanto stdout como stderr
# - Maneje errores gracefully
#
# Prueba con:
# ```python
# # Comando que termina rápido
# ejecutar_con_timeout("echo Hola", timeout=5)
#
# # Comando que tarda (Linux/Mac)
# ejecutar_con_timeout("sleep 10", timeout=3)
#
# # Comando que tarda (Windows)
# ejecutar_con_timeout("timeout /t 10", timeout=3)
# ```
#
# **Pista:** Usa `subprocess.TimeoutExpired` exception

# %%
# Escribe tu código aquí

# %% [markdown]
# ---
# ## BLOQUE 5: Módulo platform

# %% [markdown]
# ### Ejercicio 34: Información Completa del Sistema 🟢
#
# Usa el módulo `platform` para obtener:
# 1. Sistema operativo (`platform.system()`)
# 2. Versión del SO (`platform.version()`)
# 3. Release del SO (`platform.release()`)
# 4. Arquitectura (`platform.machine()`)
# 5. Nombre de la máquina (`platform.node()`)
# 6. Procesador (`platform.processor()`)
# 7. Versión de Python (`platform.python_version()`)
#
# Crea un reporte formateado tipo "About System".
#
# **Pista:** También explora `platform.uname()`

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 35: Detector de Compatibilidad 🟡
#
# Crea una función `verificar_compatibilidad()` que:
# - Detecte el SO y su versión
# - Verifique si cumple con requisitos mínimos:
#   - Windows 10+
#   - macOS 10.14+
#   - Linux kernel 4.0+
# - Verifique la versión de Python (3.7+)
# - Verifique la arquitectura (64 bits)
#
# Retorna un diccionario con:
# ```python
# {
#     "compatible": True/False,
#     "problemas": [lista de problemas encontrados],
#     "advertencias": [lista de advertencias]
# }
# ```
#
# **Pista:** Usa `platform.python_version_tuple()` y compara versiones

# %%
# Escribe tu código aquí

# %% [markdown]
# ---
# ## BLOQUE 6: Módulo shutil

# %% [markdown]
# ### Ejercicio 36: Sistema de Backup 🟡
#
# Crea una función `crear_backup(origen, destino)` que:
# 1. Copie un directorio completo recursivamente
# 2. Agregue timestamp al nombre del backup
# 3. Comprima el backup en formato `.zip`
# 4. Calcule y muestre:
#    - Tamaño original
#    - Tamaño comprimido
#    - Ratio de compresión
#
# Ejemplo:
# ```python
# crear_backup("proyecto", "backups")
# # Crea: backups/proyecto_20260206_143022.zip
# ```
#
# **Pista:** Usa `shutil.make_archive()` y `shutil.copytree()`

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 37: Analizador de Espacio en Disco 🟡
#
# Usa `shutil.disk_usage()` para:
# 1. Obtener información de todas las unidades disponibles
# 2. Calcular:
#    - Espacio total
#    - Espacio usado
#    - Espacio libre
#    - Porcentaje de uso
# 3. Crear una alerta si el uso supera el 80%
# 4. Mostrar un gráfico de barras ASCII del uso
#
# Ejemplo de salida:
# ```
# Disco C:\
# Total: 500 GB
# Usado: 350 GB (70%)
# [████████████████████████░░░░░░░░]
# ```
#
# **Pista:** En Windows prueba con `C:\\`, en Linux con `/`

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 38: Organizador de Archivos 🔴
#
# Crea una función `organizar_archivos(directorio)` que:
# - Clasifique archivos por tipo (extensión)
# - Cree carpetas por categoría:
#   - Documentos (.pdf, .doc, .txt)
#   - Imágenes (.jpg, .png, .gif)
#   - Videos (.mp4, .avi, .mkv)
#   - Audio (.mp3, .wav, .flac)
#   - Código (.py, .js, .java)
#   - Otros
# - Mueva los archivos a sus carpetas correspondientes
# - Genere un reporte de la organización
#
# **ADVERTENCIA:** Prueba en un directorio de prueba.
#
# **Pista:** Usa `shutil.move()` y define un diccionario de categorías

# %%
# Escribe tu código aquí

# %% [markdown]
# ---
# ## BLOQUE 7: Ejercicios Integradores

# %% [markdown]
# ### Ejercicio 39: Auditor de Seguridad del Sistema 🔴
#
# Crea un script completo que realice una auditoría de seguridad básica:
#
# 1. **Información del Sistema:**
#    - SO, versión, arquitectura (platform)
#    - Variables de entorno sensibles (os.environ)
#
# 2. **Análisis de Red:**
#    - Puertos abiertos (subprocess + netstat)
#    - Conexiones activas
#
# 3. **Análisis de Archivos:**
#    - Archivos con permisos sospechosos
#    - Archivos sin extensión
#    - Archivos ocultos
#
# 4. **Análisis de Logs:**
#    - Buscar patrones de intrusión (regex)
#    - IPs sospechosas
#    - Intentos de SQL injection
#
# 5. **Generar Reporte:**
#    - Guardar en archivo con timestamp
#    - Incluir nivel de riesgo (BAJO, MEDIO, ALTO)
#    - Recomendaciones
#
# **Bonus:** Exporta el reporte en formato JSON y HTML.

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 40: Monitor de Sistema en Tiempo Real 🔴
#
# Crea un monitor que muestre en tiempo real:
#
# 1. **CPU y Memoria:**
#    - Uso actual (subprocess + comandos del SO)
#    - Top 5 procesos
#
# 2. **Disco:**
#    - Espacio disponible (shutil.disk_usage)
#    - Lectura/escritura
#
# 3. **Red:**
#    - Conexiones activas
#    - Puertos en escucha
#
# 4. **Archivos:**
#    - Archivos creados recientemente
#    - Archivos modificados
#
# El monitor debe:
# - Actualizarse cada 5 segundos
# - Limpiar la pantalla en cada actualización
# - Permitir salir con Ctrl+C
# - Guardar un log de eventos anormales
#
# **Pista:** Usa `os.system('clear')` o `os.system('cls')` y un bucle infinito

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 41: Sistema de Gestión de Logs 🔴
#
# Crea un sistema completo de gestión de logs que:
#
# 1. **Recolección:**
#    - Busque archivos .log en el sistema (os.walk)
#    - Identifique logs por tipo (Apache, sistema, aplicación)
#
# 2. **Análisis:**
#    - Extraiga IPs, URLs, User-Agents (regex)
#    - Detecte errores (códigos 4xx, 5xx)
#    - Identifique patrones sospechosos
#
# 3. **Estadísticas:**
#    - Top IPs por solicitudes
#    - Top URLs visitadas
#    - Distribución de códigos HTTP
#    - Solicitudes por hora
#
# 4. **Alertas:**
#    - Ataques DDoS (muchas solicitudes de una IP)
#    - SQL injection
#    - Path traversal
#
# 5. **Rotación:**
#    - Comprimir logs antiguos (shutil)
#    - Eliminar logs muy antiguos
#
# 6. **Reporte:**
#    - Generar resumen ejecutivo
#    - Exportar a JSON/HTML
#
# **Bonus:** Crea un dashboard visual simple en HTML.

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 42: Analizador Forense Básico 🔴🔴
#
# Crea una herramienta forense que analice un directorio sospechoso:
#
# 1. **Timeline de Actividad:**
#    - Fecha de creación de archivos
#    - Fecha de modificación
#    - Fecha de último acceso
#    - Genera una línea temporal
#
# 2. **Análisis de Contenido:**
#    - Buscar palabras clave sensibles
#    - Detectar archivos cifrados
#    - Identificar scripts maliciosos (regex patterns)
#
# 3. **Hash de Archivos:**
#    - Calcular MD5/SHA256 de cada archivo
#    - Comparar con base de datos de malware conocido
#    - Detectar archivos duplicados
#
# 4. **Metadatos:**
#    - Extraer EXIF de imágenes (simular)
#    - Extraer propiedades de documentos
#
# 5. **Red:**
#    - Extraer IPs hardcoded en archivos
#    - Extraer URLs
#    - Extraer dominios
#
# 6. **Reporte Forense:**
#    - Chain of custody (quién, qué, cuándo)
#    - Hallazgos principales
#    - Nivel de amenaza
#    - Recomendaciones
#
# La herramienta debe:
# - NO modificar archivos originales
# - Registrar todas las acciones
# - Generar reporte completo
# - Ser reproducible
#
# **ADVERTENCIA:** Solo para propósitos educativos en entornos controlados.

# %%
# Escribe tu código aquí
